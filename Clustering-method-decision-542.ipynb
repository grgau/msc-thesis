# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  

from sklearn.cluster import KMeans, SpectralClustering, DBSCAN, OPTICS, AgglomerativeClustering
from scipy.spatial.distance import cdist, pdist
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from sklearn.neighbors import kneighbors_graph

from sklearn.metrics import silhouette_score, davies_bouldin_score

from sklearn.manifold import TSNE
import seaborn as sns

# %%
# plt.figure(figsize=(20,10))

# ############################## Agglomerative 20
# # colors = ["#4b0082", "#ff0000", "#ffa500", "#ffff00", "#00ff00", "#00ffff", "#0000ff", "#ff00ff", "#fa8072", "#6495ed", "#ff1493", "#98fb98"]
# # colors = ["#696969", "#006400", "#4b0082", "#ff0000", "#ffa500", "#ffff00", "#00ff00", "#00ffff", "#0000ff", "#ff00ff", "#fa8072", "#6495ed", "#ff1493", "#98fb98", "#ffe4b5", "#8b0000", "#808000", "#4169e1", "#2f4f4f"]

# X = pd.read_csv('theano-to-tf/src/tf/855_codes_prediction.csv', header=None)
# # colors = ["#000000", "#d3d3d3", "#556b2f", "#8b4513", "#483d8b", "#008000", "#008b8b", "#9acd32", "#9932cc", "#ff4500", "#ffa500", "#ffff00", "#7fff00", "#00ff7f", "#dc143c", "#00bfff", "#0000ff", "#ff00ff", "#1e90ff", "#f0e68c", "#dda0dd", "#ff1493", "#ffa07a", "#7fffd4"]
# colors = ["#000000", "#d3d3d3", "#556b2f", "#8b4513", "#483d8b", "#008000", "#008b8b", "#9acd32", "#9932cc", "#ff4500", "#ffa500", "#ffff00", "#7fff00", "#00ff7f", "#dc143c", "#00bfff", "#0000ff", "#ff00ff", "#1e90ff", "#f0e68c", "#dda0dd", "#ff1493", "#ffa07a", "#7fffd4"]

# clusterer = linkage(X.iloc[:, 1:], method='ward', metric='euclidean')
# labels = fcluster(clusterer, 20, criterion='maxclust')

# X["Cluster"] = labels.T
# df = X.reset_index(drop=True)
# X, y = df.iloc[:, 1:-1], df.iloc[:, [-1]].values

# feat_cols = list(df.columns.values[0:-1])
# tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=3000, random_state=0)
# tsne_results = tsne.fit_transform(X)

# df = pd.DataFrame(X,columns=feat_cols)
# df['Cluster'] = y
# df['label'] = df['Cluster'].apply(lambda i: str(i))
# df['tsne-2d-one'] = tsne_results[:,0]
# df['tsne-2d-two'] = tsne_results[:,1]

# ax1 = plt.subplot(1, 2, 1)
# ax1.title.set_text('Agglomerative Clustering (Ward - Euclidean - k=24)')
# sns.scatterplot(
#     x="tsne-2d-one", y="tsne-2d-two",
#     hue="Cluster",
#     palette=sns.color_palette(colors, len(set(labels))),
#     data=df,
#     legend="full",
#     alpha=0.3,
#     ax=ax1
# )


# ############################## Agglomerative 30

# X = pd.read_csv('theano-to-tf/src/tf/855_codes_prediction.csv', header=None)
# # colors = ["#000000", "#696969", "#556b2f", "#8b4513", "#808000", "#483d8b", "#008000", "#3cb371", "#008080", "#4682b4", "#00008b", "#32cd32", "#daa520", "#800080", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#00ff00", "#9400d3", "#00fa9a", "#dc143c", "#0000ff", "#adff2f", "#d8bfd8", "#ff7f50", "#ff00ff", "#1e90ff", "#db7093", "#f0e68c", "#ffff54", "#7b68ee", "#ee82ee", "#87cefa", "#7fffd4"]
# colors = ["#000000", "#696969", "#556b2f", "#8b4513", "#808000", "#483d8b", "#008000", "#3cb371", "#008080", "#4682b4", "#00008b", "#32cd32", "#daa520", "#800080", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#00ff00", "#9400d3", "#00fa9a", "#dc143c", "#0000ff", "#adff2f", "#d8bfd8", "#ff7f50", "#ff00ff", "#1e90ff", "#db7093", "#f0e68c", "#ffff54", "#7b68ee", "#ee82ee", "#87cefa", "#7fffd4"]

# clusterer = linkage(X, method='ward', metric='euclidean')
# labels = fcluster(clusterer, 36, criterion='maxclust')

# X["Cluster"] = labels.T
# df = X.reset_index(drop=True)
# X, y = df.iloc[:, 1:-1], df.iloc[:, [-1]].values

# feat_cols = list(df.columns.values[0:-1])
# tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=3000, random_state=0)
# tsne_results = tsne.fit_transform(X)

# df = pd.DataFrame(X,columns=feat_cols)
# df['Cluster'] = y
# df['label'] = df['Cluster'].apply(lambda i: str(i))
# df['tsne-2d-one'] = tsne_results[:,0]
# df['tsne-2d-two'] = tsne_results[:,1]

# ax2 = plt.subplot(1, 2, 2)
# ax2.title.set_text('Agglomerative Clustering (Ward - Euclidean - k=36)')
# sns.scatterplot(
#     x="tsne-2d-one", y="tsne-2d-two",
#     hue="Cluster",
#     palette=sns.color_palette(colors, len(set(labels))),
#     data=df,
#     legend="full",
#     alpha=0.3,
#     ax=ax2
# )

# %%
# plt.figure(figsize=(20,20))

# ############################## Agglomerative 19

# X = pd.read_csv('theano-to-tf/lig_855_codes_prediction.csv', header=None)
# print(X.shape)
# colors = ["#4b0082", "#ff0000", "#ffa500", "#ffff00", "#00ff00", "#00ffff", "#0000ff", "#ff00ff", "#fa8072", "#6495ed", "#ff1493", "#98fb98"]
# clusterer = linkage(X, method='ward', metric='euclidean')
# labels = fcluster(clusterer, 12, criterion='maxclust')

# X["Cluster"] = labels.T
# df = X.reset_index(drop=True)
# X, y = df.iloc[:, :-1], df.iloc[:, [-1]].values

# feat_cols = list(df.columns.values[0:-1])
# tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=5000, random_state=0)
# tsne_results = tsne.fit_transform(X)

# df = pd.DataFrame(X,columns=feat_cols)
# df['Cluster'] = y
# df['label'] = df['Cluster'].apply(lambda i: str(i))
# df['tsne-2d-one'] = tsne_results[:,0]
# df['tsne-2d-two'] = tsne_results[:,1]

# ax3 = plt.subplot(2, 2, 3)
# ax3.title.set_text('Agglomerative Clustering (Complete - Euclidean - k=12)')
# sns.scatterplot(
#     x="tsne-2d-one", y="tsne-2d-two",
#     hue="Cluster",
#     palette=sns.color_palette(colors, len(set(labels))),
#     data=df,
#     legend="full",
#     alpha=0.3,
#     ax=ax3
# )

# %% [markdown]
# ### 855

# %%
# Ler dataset
# df = pd.read_csv('theano-to-tf/src/tf/855_codes_prediction.csv', header=None)
df = pd.read_csv('theano-to-tf/855-attentionhcare-542-codes_prediction.csv', header=None)
df = df.iloc[:,1:]
# df = pd.read_csv('theano-to-tf/lig_855_codes_prediction.csv', header=None)

# %%
df
# Out:
#            1         2         3         4         5         6         7    \
# 0     0.052078  0.024128  0.013086  0.022637  0.033582  0.034635  0.013126
# 1     0.017799  0.052254  0.065876  0.046032  0.074100  0.010055  0.022169
# 2     0.060746  0.020489  0.014800  0.029163  0.010993  0.018718  0.025754
# 3     0.080425  0.015268  0.011231  0.028359  0.077702  0.017210  0.014577
# 4     0.056889  0.035672  0.037909  0.031377  0.085911  0.012200  0.014121
# ...        ...       ...       ...       ...       ...       ...       ...
# 7477  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7478  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7479  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7480  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7481  0.050871  0.004678  0.035439  0.015306  0.051424  0.022095  0.001812
#
# ...

# %%
range_n_clusters = range(10, 41)

sh_score_linkage = []
db_index_linkage = []

sh_score_kmeans = []
db_index_kmeans = []

sh_score_spectral = []
db_index_spectral = []

sh_score_linkage_10 = []
db_index_linkage_10 = []

sh_score_linkage_20 = []
db_index_linkage_20 = []


for n_clusters in range_n_clusters:
#     clusterer = linkage(df, method='ward', metric='euclidean')
#     labels = fcluster(clusterer, n_clusters, criterion='maxclust')
    labels = AgglomerativeClustering(n_clusters=n_clusters).fit_predict(df)
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_linkage.append(db_index)
    sh_score_linkage.append(sh_score)
    print("Linkage W\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}".format(n_clusters, sh_score, db_index))

    knn_graph = kneighbors_graph(df, 10, include_self=False)
    labels = AgglomerativeClustering(n_clusters=n_clusters, connectivity=knn_graph).fit_predict(df)
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_linkage_10.append(db_index)
    sh_score_linkage_10.append(sh_score)
    print("Linkage k=10 W\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}".format(n_clusters, sh_score, db_index))

    knn_graph = kneighbors_graph(df, 20, include_self=False)
    labels = AgglomerativeClustering(n_clusters=n_clusters, connectivity=knn_graph).fit_predict(df)
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_linkage_20.append(db_index)
    sh_score_linkage_20.append(sh_score)
    print("Linkage k=20 W\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}".format(n_clusters, sh_score, db_index))
    
    labels = KMeans(n_clusters=n_clusters, random_state=0).fit_predict(df)
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_kmeans.append(db_index)
    sh_score_kmeans.append(sh_score)
    print("K-Means\t\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}".format(n_clusters, sh_score, db_index))    
    
    clusterer = SpectralClustering(n_clusters=n_clusters, assign_labels="discretize", random_state=0).fit(df)
    labels = clusterer.labels_
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_spectral.append(db_index)
    sh_score_spectral.append(sh_score)
    print("Spectral\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}\n\n".format(n_clusters, sh_score, db_index))
# Out:
# Linkage W	n_clusters:10	 silhouette score:0.03684	 db index:1.92996
# /usr/local/lib/python3.8/site-packages/sklearn/cluster/_agglomerative.py:245: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
#   connectivity, n_connected_components = _fix_connectivity(
# Linkage k=10 W	n_clusters:10	 silhouette score:0.03629	 db index:2.48546
# Linkage k=20 W	n_clusters:10	 silhouette score:0.07258	 db index:2.31346
# K-Means		n_clusters:10	 silhouette score:0.10820	 db index:1.95110
# Spectral	n_clusters:10	 silhouette score:0.09766	 db index:2.35038
#
#
# Linkage W	n_clusters:11	 silhouette score:0.04238	 db index:2.30814
# /usr/local/lib/python3.8/site-packages/sklearn/cluster/_agglomerative.py:245: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
#   connectivity, n_connected_components = _fix_connectivity(
# ...

# %%
x = range(10, 41)
plt.figure(figsize=(16,13))


ax1 = plt.subplot(3, 2, 1)
ax1.plot(x, sh_score_linkage, 'r--o')
ax1.grid(axis='both')
ax1.set_title("Linkage Ward Silhouette Score")
ax1.set_ylabel('Silhouette Scores')
ax1.set_xlabel('Number of Clusters')

ax2 = plt.subplot(3, 2, 2)
ax2.plot(x, db_index_linkage, 'c--o')
ax2.grid(axis='both')
ax2.set_title("Linkage Ward DB Index")
ax2.set_ylabel('DB Index')
ax2.set_xlabel('Number of Clusters')


ax3 = plt.subplot(3, 2, 3)
ax3.plot(x, sh_score_linkage_10, 'r--o')
ax3.set_title("Linkage Ward Silhouette Score (KNN - K=10)")
ax3.grid(axis='both')
ax3.set_ylabel('Silhouette Scores')
ax3.set_xlabel('Number of Clusters')

ax4 = plt.subplot(3, 2, 4)
ax4.plot(x, db_index_linkage_10, 'c--o')
ax4.grid(axis='both')
ax4.set_title("Linkage Ward DB Index (KNN - K=10)")
ax4.set_ylabel('DB Index')
ax4.set_xlabel('Number of Clusters')


ax5 = plt.subplot(3, 2, 5)
ax5.plot(x, sh_score_linkage_20, 'r--o')
ax5.grid(axis='both')
ax5.set_title("Linkage Ward Silhouette Score (KNN - K=20)")
ax5.set_ylabel('Silhouette Scores')
ax5.set_xlabel('Number of Clusters')

ax6 = plt.subplot(3, 2, 6)
ax6.plot(x, db_index_linkage_20, 'c--o')
ax6.grid(axis='both')
ax6.set_title("Linkage Ward DB Index (KNN - K=20)")
ax6.set_ylabel('DB Index')
ax6.set_xlabel('Number of Clusters')


plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()


## OBS 25 Clusters do knn=20 parece ser o melhor resultado

# %%
x = range(10, 41)
plt.figure(figsize=(16,13))

ax1 = plt.subplot(2, 2, 1)
ax1.plot(x, sh_score_kmeans, 'r--o')
ax1.set_title("K-Means Silhouette Score")
ax1.grid(axis='both')
ax1.set_ylabel('Silhouette Scores')
ax1.set_xlabel('Number of Clusters')

ax2 = plt.subplot(2, 2, 2)
ax2.plot(x, db_index_kmeans, 'c--o')
ax2.grid(axis='both')
ax2.set_title("K-Means DB Index")
ax2.set_ylabel('DB Index')
ax2.set_xlabel('Number of Clusters')


ax3 = plt.subplot(2, 2, 3)
ax3.plot(x, sh_score_spectral, 'r--o')
ax3.grid(axis='both')
ax3.set_title("Spectral Silhouette Score")
ax3.set_ylabel('Silhouette Scores')
ax3.set_xlabel('Number of Clusters')

ax4 = plt.subplot(2, 2, 4)
ax4.plot(x, db_index_spectral, 'c--o')
ax4.grid(axis='both')
ax4.set_title("Spectral DB Index")
ax4.set_ylabel('DB Index')
ax4.set_xlabel('Number of Clusters')
# Out:
# Text(0.5, 0, 'Number of Clusters')

# %%
distances = ['euclidean', 'cityblock', 'minkowski']
methods = ['single', 'complete', 'average', 'weighted']

fig, axes = plt.subplots(4, 3, figsize=(40, 50))
plt.title('Hierarchical Clustering Dendrograms')

col = 0
row = 0
graphs = []
dns = []

for method in methods:
    for distance in distances:
        try:
            print(method + " - " + distance)
            Z = linkage(df, method=method, metric=distance)
            dn = dendrogram(Z, ax=axes[row, col], truncate_mode='lastp', p=50, leaf_rotation=90., leaf_font_size=8., orientation="top")
            axes[row, col].set_xlabel('Sample index', fontsize=28)
            axes[row, col].set_ylabel('Distance', fontsize=28)
            axes[row, col].set_title(method.title() + " - " + distance.title(), fontsize=40)
            graphs.append(axes[row, col])
            dns.append(dn)
        except:
            axes[row, col].set_xlabel('Sample index', fontsize=28)
            axes[row, col].set_ylabel('Distance', fontsize=28)
            axes[row, col].set_title(method.title() + " - " + distance.title(), fontsize=40)
            graphs.append(axes[row, col])
            print("Invalid: " + method + " - " + distance)
        col += 1
    row += 1
    col = 0

plt.show()
# Out:
# single - euclidean
# single - cityblock
# single - minkowski
# complete - euclidean
# complete - cityblock
# complete - minkowski
# average - euclidean
# average - cityblock
# average - minkowski
# weighted - euclidean
# weighted - cityblock
# weighted - minkowski

# %%
distances = ['euclidean', 'cityblock', 'minkowski']
methods = ['centroid', 'median', 'ward']

fig, axes = plt.subplots(3, 3, figsize=(40, 50))
plt.title('Hierarchical Clustering Dendrograms')

col = 0
row = 0
graphs = []
dns = []

for method in methods:
    for distance in distances:
        try:
            print(method + " - " + distance)
            Z = linkage(df, method=method, metric=distance)
            dn = dendrogram(Z, ax=axes[row, col], truncate_mode='lastp', p=50, leaf_rotation=90., leaf_font_size=8., orientation="top")
            axes[row, col].set_xlabel('Sample index', fontsize=28)
            axes[row, col].set_ylabel('Distance', fontsize=28)
            axes[row, col].set_title(method.title() + " - " + distance.title(), fontsize=40)
            graphs.append(axes[row, col])
            dns.append(dn)
        except:
            axes[row, col].set_xlabel('Sample index', fontsize=28)
            axes[row, col].set_ylabel('Distance', fontsize=28)
            axes[row, col].set_title(method.title() + " - " + distance.title(), fontsize=40)
            graphs.append(axes[row, col])
            print("Invalid: " + method + " - " + distance)
        col += 1
    row += 1
    col = 0

plt.show()
# Out:
# centroid - euclidean
# centroid - cityblock
# Invalid: centroid - cityblock
# centroid - minkowski
# Invalid: centroid - minkowski
# median - euclidean
# median - cityblock
# Invalid: median - cityblock
# median - minkowski
# Invalid: median - minkowski
# ward - euclidean
# ward - cityblock
# Invalid: ward - cityblock
# ward - minkowski
# Invalid: ward - minkowski

# %%
plt.figure(figsize=(20,10))

############################## K-means k=24

X = pd.read_csv('theano-to-tf/855-attentionhcare-542-codes_prediction.csv', header=None)
X = X.iloc[:,1:]
# colors = ["#000000", "#696969", "#556b2f", "#8b4513", "#808000", "#483d8b", "#008000", "#3cb371", "#008080", "#4682b4", "#00008b", "#32cd32", "#daa520", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#9400d3", "#00fa9a", "#dc143c", "#adff2f", "#d8bfd8", "#ff7f50", "#ff00ff", "#1e90ff", "#f0e68c", "#ffff54", "#7b68ee", "#ee82ee"]
colors = ["#000000", "#696969", "#556b2f", "#8b4513", "#808000", "#483d8b", "#008000", "#3cb371", "#008080", "#4682b4", "#00008b", "#32cd32", "#daa520", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#9400d3", "#00fa9a", "#dc143c", "#adff2f", "#d8bfd8", "#ff7f50"]

labels = KMeans(n_clusters=24, random_state=0).fit_predict(X)

tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=5000, random_state=0)
tsne_results = tsne.fit_transform(X)

df = pd.DataFrame({'tsne-2d-one': tsne_results[:,0], 'tsne-2d-two': tsne_results[:,1]})
df['Cluster'] = labels.T

ax2 = plt.subplot(1, 2, 2)
ax2.title.set_text('K-means Clustering (Euclidean - k=24)')
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Cluster",
    palette=sns.color_palette(colors, len(set(labels))),
    data=df,
    legend="full",
    alpha=0.3,
    ax=ax2
)

############################## Linkage k=26 knn=20

X = pd.read_csv('theano-to-tf/855-attentionhcare-542-codes_prediction.csv', header=None)
X = X.iloc[:,1:]
colors = ["#000000", "#696969", "#556b2f", "#8b4513", "#808000", "#483d8b", "#008000", "#3cb371", "#008080", "#4682b4", "#00008b", "#32cd32", "#daa520", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#9400d3", "#00fa9a", "#dc143c", "#adff2f", "#d8bfd8", "#ff7f50", "#ff00ff", "#ffff54"]
# colors = ["#000000", "#8b4513", "#808000", "#483d8b", "#008080", "#4682b4", "#00008b", "#800080", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#00ff00", "#dc143c", "#0000ff", "#adff2f", "#d8bfd8", "#ff7f50", "#ff00ff", "#1e90ff", "#ffff54", "#7b68ee", "#ee82ee", "#87cefa"]

knn_graph = kneighbors_graph(df, 20, include_self=False)
labels = AgglomerativeClustering(n_clusters=26, connectivity=knn_graph).fit_predict(X)

#perplexity = 30 melhor até agora
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=5000, random_state=0)
tsne_results = tsne.fit_transform(X)

df = pd.DataFrame({'tsne-2d-one': tsne_results[:,0], 'tsne-2d-two': tsne_results[:,1]})
df['Cluster'] = labels.T

ax1 = plt.subplot(1, 2, 1)
ax1.title.set_text('Ward Agglomerative Clustering (Euclidean - k=26 knn=20)')
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Cluster",
    palette=sns.color_palette(colors, len(set(labels))),
    data=df,
    legend="full",
    alpha=0.3,
    ax=ax1
)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 7482 samples in 0.956s...
# [t-SNE] Computed neighbors for 7482 samples in 198.336s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7482
# [t-SNE] Computed conditional probabilities for sample 2000 / 7482
# [t-SNE] Computed conditional probabilities for sample 3000 / 7482
# [t-SNE] Computed conditional probabilities for sample 4000 / 7482
# [t-SNE] Computed conditional probabilities for sample 5000 / 7482
# [t-SNE] Computed conditional probabilities for sample 6000 / 7482
# [t-SNE] Computed conditional probabilities for sample 7000 / 7482
# [t-SNE] Computed conditional probabilities for sample 7482 / 7482
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.903900
# [t-SNE] KL divergence after 5000 iterations: 1.816837
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 7482 samples in 0.968s...
# ...

# %%
plt.figure(figsize=(20,10))

############################## K-means k=24

X = pd.read_csv('theano-to-tf/855-attentionhcare-542-codes_prediction.csv', header=None)
X = X.iloc[:,1:]
# colors = ["#000000", "#696969", "#556b2f", "#8b4513", "#808000", "#483d8b", "#008000", "#3cb371", "#008080", "#4682b4", "#00008b", "#32cd32", "#daa520", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#9400d3", "#00fa9a", "#dc143c", "#adff2f", "#d8bfd8", "#ff7f50", "#ff00ff", "#1e90ff", "#f0e68c", "#ffff54", "#7b68ee", "#ee82ee"]
colors = ["#000000", "#696969", "#556b2f", "#8b4513", "#808000", "#483d8b", "#008000", "#3cb371", "#008080", "#4682b4", "#00008b", "#32cd32", "#daa520", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#9400d3", "#00fa9a", "#dc143c", "#adff2f", "#d8bfd8", "#ff7f50"]

labels = KMeans(n_clusters=24, random_state=0).fit_predict(X)

tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=5000, random_state=0)
tsne_results = tsne.fit_transform(X)

df = pd.DataFrame({'tsne-2d-one': tsne_results[:,0], 'tsne-2d-two': tsne_results[:,1]})
df['Cluster'] = labels.T

ax2 = plt.subplot(1, 2, 2)
ax2.title.set_text('K-means Clustering (Euclidean - k=24)')
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Cluster",
    palette=sns.color_palette(colors, len(set(labels))),
    data=df,
    legend="full",
    alpha=0.3,
    ax=ax2
)

############################## Linkage k=26 knn=20

X = pd.read_csv('theano-to-tf/855-attentionhcare-542-codes_prediction.csv', header=None)
X = X.iloc[:,1:]
colors = ["#000000", "#696969", "#556b2f", "#8b4513", "#808000", "#483d8b", "#008000", "#3cb371", "#008080", "#4682b4", "#00008b", "#32cd32", "#daa520", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#9400d3", "#00fa9a", "#dc143c", "#adff2f", "#d8bfd8", "#ff7f50", "#ff00ff", "#ffff54"]
# colors = ["#000000", "#8b4513", "#808000", "#483d8b", "#008080", "#4682b4", "#00008b", "#800080", "#d2b48c", "#ff0000", "#00ced1", "#ff8c00", "#c71585", "#00ff00", "#dc143c", "#0000ff", "#adff2f", "#d8bfd8", "#ff7f50", "#ff00ff", "#1e90ff", "#ffff54", "#7b68ee", "#ee82ee", "#87cefa"]

knn_graph = kneighbors_graph(X, 20, include_self=True)
labels = AgglomerativeClustering(n_clusters=26, connectivity=knn_graph).fit_predict(X)

#perplexity = 30 melhor até agora
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=5000, random_state=0)
tsne_results = tsne.fit_transform(X)

df = pd.DataFrame({'tsne-2d-one': tsne_results[:,0], 'tsne-2d-two': tsne_results[:,1]})
df['Cluster'] = labels.T

ax1 = plt.subplot(1, 2, 1)
ax1.title.set_text('Ward Agglomerative Clustering (Euclidean - k=26 knn=20)')
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Cluster",
    palette=sns.color_palette(colors, len(set(labels))),
    data=df,
    legend="full",
    alpha=0.3,
    ax=ax1
)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 7482 samples in 0.580s...
# [t-SNE] Computed neighbors for 7482 samples in 79.478s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7482
# [t-SNE] Computed conditional probabilities for sample 2000 / 7482
# [t-SNE] Computed conditional probabilities for sample 3000 / 7482
# [t-SNE] Computed conditional probabilities for sample 4000 / 7482
# [t-SNE] Computed conditional probabilities for sample 5000 / 7482
# [t-SNE] Computed conditional probabilities for sample 6000 / 7482
# [t-SNE] Computed conditional probabilities for sample 7000 / 7482
# [t-SNE] Computed conditional probabilities for sample 7482 / 7482
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.903900
# [t-SNE] KL divergence after 5000 iterations: 1.816837
# ...

# %% [markdown]
# ### 272

# %%
# Ler dataset
# df = pd.read_csv('theano-to-tf/src/tf/855_codes_prediction.csv', header=None)
df = pd.read_csv('theano-to-tf/272-attentionhcare-542-codes_prediction.csv', header=None)
df = df.iloc[:,1:]
# df = pd.read_csv('theano-to-tf/lig_855_codes_prediction.csv', header=None)

# %%
df
# Out:
#            1         2         3         4         5         6         7    \
# 0     0.005406  0.008626  0.026262  0.011408  0.016299  0.006108  0.048203
# 1     0.018972  0.021547  0.026574  0.084224  0.024499  0.030495  0.014596
# 2     0.072949  0.083097  0.029391  0.069929  0.019441  0.022447  0.021535
# 3     0.007407  0.008761  0.027223  0.016402  0.024168  0.024263  0.009582
# 4     0.009334  0.018864  0.035727  0.020550  0.033322  0.018917  0.016912
# ...        ...       ...       ...       ...       ...       ...       ...
# 7477  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7478  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7479  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7480  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7481  0.142230  0.020577  0.037221  0.001443  0.024902  0.002099  0.003649
#
# ...

# %%
range_n_clusters = range(10, 41)

sh_score_linkage = []
db_index_linkage = []

sh_score_kmeans = []
db_index_kmeans = []

sh_score_spectral = []
db_index_spectral = []

sh_score_linkage_10 = []
db_index_linkage_10 = []

sh_score_linkage_20 = []
db_index_linkage_20 = []


for n_clusters in range_n_clusters:
#     clusterer = linkage(df, method='ward', metric='euclidean')
#     labels = fcluster(clusterer, n_clusters, criterion='maxclust')
    labels = AgglomerativeClustering(n_clusters=n_clusters).fit_predict(df)
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_linkage.append(db_index)
    sh_score_linkage.append(sh_score)
    print("Linkage W\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}".format(n_clusters, sh_score, db_index))

    knn_graph = kneighbors_graph(df, 10, include_self=False)
    labels = AgglomerativeClustering(n_clusters=n_clusters, connectivity=knn_graph).fit_predict(df)
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_linkage_10.append(db_index)
    sh_score_linkage_10.append(sh_score)
    print("Linkage k=10 W\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}".format(n_clusters, sh_score, db_index))

    knn_graph = kneighbors_graph(df, 20, include_self=False)
    labels = AgglomerativeClustering(n_clusters=n_clusters, connectivity=knn_graph).fit_predict(df)
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_linkage_20.append(db_index)
    sh_score_linkage_20.append(sh_score)
    print("Linkage k=20 W\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}".format(n_clusters, sh_score, db_index))
    
    labels = KMeans(n_clusters=n_clusters, random_state=0).fit_predict(df)
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_kmeans.append(db_index)
    sh_score_kmeans.append(sh_score)
    print("K-Means\t\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}".format(n_clusters, sh_score, db_index))    
    
    clusterer = SpectralClustering(n_clusters=n_clusters, assign_labels="discretize", random_state=0).fit(df)
    labels = clusterer.labels_
    db_index = davies_bouldin_score(df, labels)
    sh_score = silhouette_score(df, labels)
    db_index_spectral.append(db_index)
    sh_score_spectral.append(sh_score)
    print("Spectral\tn_clusters:{}\t silhouette score:{:.5f}\t db index:{:.5f}\n\n".format(n_clusters, sh_score, db_index))
# Out:
# Linkage W	n_clusters:10	 silhouette score:0.01380	 db index:2.32805
# /usr/local/lib/python3.8/site-packages/sklearn/cluster/_agglomerative.py:245: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
#   connectivity, n_connected_components = _fix_connectivity(
# Linkage k=10 W	n_clusters:10	 silhouette score:0.02975	 db index:2.35629
# /usr/local/lib/python3.8/site-packages/sklearn/cluster/_agglomerative.py:245: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
#   connectivity, n_connected_components = _fix_connectivity(
# Linkage k=20 W	n_clusters:10	 silhouette score:0.02717	 db index:2.33197
# K-Means		n_clusters:10	 silhouette score:0.10286	 db index:2.09537
# Spectral	n_clusters:10	 silhouette score:0.08758	 db index:2.52801
#
#
# Linkage W	n_clusters:11	 silhouette score:0.02148	 db index:2.39302
# ...

# %%
x = range(10, 41)
plt.figure(figsize=(16,13))


ax1 = plt.subplot(3, 2, 1)
ax1.plot(x, sh_score_linkage, 'r--o')
ax1.grid(axis='both')
ax1.set_title("Linkage Ward Silhouette Score")
ax1.set_ylabel('Silhouette Scores')
ax1.set_xlabel('Number of Clusters')

ax2 = plt.subplot(3, 2, 2)
ax2.plot(x, db_index_linkage, 'c--o')
ax2.grid(axis='both')
ax2.set_title("Linkage Ward DB Index")
ax2.set_ylabel('DB Index')
ax2.set_xlabel('Number of Clusters')


ax3 = plt.subplot(3, 2, 3)
ax3.plot(x, sh_score_linkage_10, 'r--o')
ax3.set_title("Linkage Ward Silhouette Score (KNN - K=10)")
ax3.grid(axis='both')
ax3.set_ylabel('Silhouette Scores')
ax3.set_xlabel('Number of Clusters')

ax4 = plt.subplot(3, 2, 4)
ax4.plot(x, db_index_linkage_10, 'c--o')
ax4.grid(axis='both')
ax4.set_title("Linkage Ward DB Index (KNN - K=10)")
ax4.set_ylabel('DB Index')
ax4.set_xlabel('Number of Clusters')


ax5 = plt.subplot(3, 2, 5)
ax5.plot(x, sh_score_linkage_20, 'r--o')
ax5.grid(axis='both')
ax5.set_title("Linkage Ward Silhouette Score (KNN - K=20)")
ax5.set_ylabel('Silhouette Scores')
ax5.set_xlabel('Number of Clusters')

ax6 = plt.subplot(3, 2, 6)
ax6.plot(x, db_index_linkage_20, 'c--o')
ax6.grid(axis='both')
ax6.set_title("Linkage Ward DB Index (KNN - K=20)")
ax6.set_ylabel('DB Index')
ax6.set_xlabel('Number of Clusters')


plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()


## OBS 25 Clusters do knn=20 parece ser o melhor resultado

# %%
x = range(10, 41)
plt.figure(figsize=(16,13))

ax1 = plt.subplot(2, 2, 1)
ax1.plot(x, sh_score_kmeans, 'r--o')
ax1.set_title("K-Means Silhouette Score")
ax1.grid(axis='both')
ax1.set_ylabel('Silhouette Scores')
ax1.set_xlabel('Number of Clusters')

ax2 = plt.subplot(2, 2, 2)
ax2.plot(x, db_index_kmeans, 'c--o')
ax2.grid(axis='both')
ax2.set_title("K-Means DB Index")
ax2.set_ylabel('DB Index')
ax2.set_xlabel('Number of Clusters')


ax3 = plt.subplot(2, 2, 3)
ax3.plot(x, sh_score_spectral, 'r--o')
ax3.grid(axis='both')
ax3.set_title("Spectral Silhouette Score")
ax3.set_ylabel('Silhouette Scores')
ax3.set_xlabel('Number of Clusters')

ax4 = plt.subplot(2, 2, 4)
ax4.plot(x, db_index_spectral, 'c--o')
ax4.grid(axis='both')
ax4.set_title("Spectral DB Index")
ax4.set_ylabel('DB Index')
ax4.set_xlabel('Number of Clusters')
# Out:
# Text(0.5, 0, 'Number of Clusters')

# %%
distances = ['euclidean', 'cityblock', 'minkowski']
methods = ['single', 'complete', 'average', 'weighted']

fig, axes = plt.subplots(4, 3, figsize=(40, 50))
plt.title('Hierarchical Clustering Dendrograms')

col = 0
row = 0
graphs = []
dns = []

for method in methods:
    for distance in distances:
        try:
            print(method + " - " + distance)
            Z = linkage(df, method=method, metric=distance)
            dn = dendrogram(Z, ax=axes[row, col], truncate_mode='lastp', p=50, leaf_rotation=90., leaf_font_size=8., orientation="top")
            axes[row, col].set_xlabel('Sample index', fontsize=28)
            axes[row, col].set_ylabel('Distance', fontsize=28)
            axes[row, col].set_title(method.title() + " - " + distance.title(), fontsize=40)
            graphs.append(axes[row, col])
            dns.append(dn)
        except:
            axes[row, col].set_xlabel('Sample index', fontsize=28)
            axes[row, col].set_ylabel('Distance', fontsize=28)
            axes[row, col].set_title(method.title() + " - " + distance.title(), fontsize=40)
            graphs.append(axes[row, col])
            print("Invalid: " + method + " - " + distance)
        col += 1
    row += 1
    col = 0

plt.show()
# Out:
# single - euclidean
# single - cityblock
# single - minkowski
# complete - euclidean
# complete - cityblock
# complete - minkowski
# average - euclidean
# average - cityblock
# average - minkowski
# weighted - euclidean
# weighted - cityblock
# weighted - minkowski

# %%
distances = ['euclidean', 'cityblock', 'minkowski']
methods = ['centroid', 'median', 'ward']

fig, axes = plt.subplots(3, 3, figsize=(40, 50))
plt.title('Hierarchical Clustering Dendrograms')

col = 0
row = 0
graphs = []
dns = []

for method in methods:
    for distance in distances:
        try:
            print(method + " - " + distance)
            Z = linkage(df, method=method, metric=distance)
            dn = dendrogram(Z, ax=axes[row, col], truncate_mode='lastp', p=50, leaf_rotation=90., leaf_font_size=8., orientation="top")
            axes[row, col].set_xlabel('Sample index', fontsize=28)
            axes[row, col].set_ylabel('Distance', fontsize=28)
            axes[row, col].set_title(method.title() + " - " + distance.title(), fontsize=40)
            graphs.append(axes[row, col])
            dns.append(dn)
        except:
            axes[row, col].set_xlabel('Sample index', fontsize=28)
            axes[row, col].set_ylabel('Distance', fontsize=28)
            axes[row, col].set_title(method.title() + " - " + distance.title(), fontsize=40)
            graphs.append(axes[row, col])
            print("Invalid: " + method + " - " + distance)
        col += 1
    row += 1
    col = 0

plt.show()
# Out:
# centroid - euclidean
# centroid - cityblock
# Invalid: centroid - cityblock
# centroid - minkowski
# Invalid: centroid - minkowski
# median - euclidean
# median - cityblock
# Invalid: median - cityblock
# median - minkowski
# Invalid: median - minkowski
# ward - euclidean
# ward - cityblock
# Invalid: ward - cityblock
# ward - minkowski
# Invalid: ward - minkowski

# %%
plt.figure(figsize=(20,10))

############################## K-means k=23

X = pd.read_csv('theano-to-tf/272-attentionhcare-542-codes_prediction.csv', header=None)
X = X.iloc[:,1:]
colors = ["#000000", "#696969", "#483d8b", "#008000", "#3cb371", "#008080", "#daa520", "#800080", "#d2b48c", "#ff0000", "#00ced1", "#9400d3", "#00fa9a", "#dc143c", "#0000ff", "#adff2f", "#d8bfd8", "#ff7f50", "#f0e68c", "#7b68ee", "#ee82ee", "#87cefa", "#ffff54"]

labels = KMeans(n_clusters=23, random_state=0).fit_predict(X)

tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=5000, random_state=0)
tsne_results = tsne.fit_transform(X)

df = pd.DataFrame({'tsne-2d-one': tsne_results[:,0], 'tsne-2d-two': tsne_results[:,1]})
df['Cluster'] = labels.T

ax2 = plt.subplot(1, 2, 2)
ax2.title.set_text('K-means Clustering (Euclidean - k=23)')
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Cluster",
    palette=sns.color_palette(colors, len(set(labels))),
    data=df,
    legend="full",
    alpha=0.3,
    ax=ax2
)

############################## Linkage k=16 knn=20

X = pd.read_csv('theano-to-tf/272-attentionhcare-542-codes_prediction.csv', header=None)
X = X.iloc[:,1:]
# colors = ["#000000", "#696969", "#483d8b", "#008000", "#3cb371", "#008080", "#daa520", "#800080", "#d2b48c", "#ff0000", "#00ced1", "#9400d3", "#00fa9a", "#dc143c", "#0000ff", "#adff2f", "#d8bfd8", "#ff7f50", "#f0e68c", "#7b68ee", "#ee82ee"]
colors = ["#000000", "#696969", "#483d8b", "#008000", "#3cb371", "#008080", "#daa520", "#800080", "#d2b48c", "#ff0000", "#00ced1", "#9400d3", "#00fa9a", "#dc143c", "#0000ff", "#adff2f"]

knn_graph = kneighbors_graph(df, 20, include_self=False)
labels = AgglomerativeClustering(n_clusters=16, connectivity=knn_graph).fit_predict(X)
# labels = AgglomerativeClustering(n_clusters=16).fit_predict(X)

tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=5000, random_state=0)
tsne_results = tsne.fit_transform(X)

df = pd.DataFrame({'tsne-2d-one': tsne_results[:,0], 'tsne-2d-two': tsne_results[:,1]})
df['Cluster'] = labels.T

ax1 = plt.subplot(1, 2, 1)
ax1.title.set_text('Ward Agglomerative Clustering (Euclidean - k=16 knn=20)')
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Cluster",
    palette=sns.color_palette(colors, len(set(labels))),
    data=df,
    legend="full",
    alpha=0.3,
    ax=ax1
)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 7482 samples in 0.431s...
# [t-SNE] Computed neighbors for 7482 samples in 54.104s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7482
# [t-SNE] Computed conditional probabilities for sample 2000 / 7482
# [t-SNE] Computed conditional probabilities for sample 3000 / 7482
# [t-SNE] Computed conditional probabilities for sample 4000 / 7482
# [t-SNE] Computed conditional probabilities for sample 5000 / 7482
# [t-SNE] Computed conditional probabilities for sample 6000 / 7482
# [t-SNE] Computed conditional probabilities for sample 7000 / 7482
# [t-SNE] Computed conditional probabilities for sample 7482 / 7482
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.757088
# [t-SNE] KL divergence after 5000 iterations: 1.922522
# ...
